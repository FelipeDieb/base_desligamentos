# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', 199)  # or 199

import seaborn as sns
from glob import glob
import re

import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.express as px
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import  LabelEncoder, OrdinalEncoder
from sklearn.impute import KNNImputer

from IPython.core.display import HTML

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

rc={'axes.labelsize': 15, 'font.size': 15, 'legend.fontsize': 15, 'axes.titlesize': 15}
plt.rcParams.update(**rc)

HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
df = pd.read_csv("df_eda.csv"); 
df.drop([col for col in df.columns.tolist() if 'Unnamed' in col] , axis = 'columns', inplace=True)

# %%
df.head()
# Out:
#    idade desligado viagens            departamento  distancia_de_casa  \
# 0   43.0        no  Rarely  Research & Development               30.0
# 1   40.0        no  Rarely         Human Resources               60.0
# 2   31.0        no  Rarely  Research & Development               80.0
# 3   49.0        no  Rarely  Research & Development              220.0
# 4   44.0        no  Rarely  Research & Development              280.0
#
#    nivel_educacional campo_da_educacao  id_do_empregado  \
# 0                  3     Life Sciences             1255
# 1                  2           Medical             1550
# 2                  5     Life Sciences             1430
# 3                  4             Other             1655
# 4                  3     Life Sciences             1523
#
#    satisfacao_com_ambiente  genero  envolvimento_com_o_trabalho  \
# 0                        3    Male                            1
# 1                        3    Male                            3
# 2                        1  Female                            3
# 3                        1  Female                            3
# 4                        4    Male                            3
#
#                cargo  satisfacao_com_trabalho  renda_mensal  \
# 0  Research Director                        4    197.000000
# 1            Manager                        4  16437.000000
# 2  Research Director                        2  16422.000000
# 3  Research Director                        2  16413.000000
# 4  Research Director                        1  13492.333333
#
#    numero_de_companhias_que_trabalhou  percentual_de_aumento_salarial  \
# 0                                   3                              14
# 1                                   1                              21
# 2                                   3                              11
# 3                                   3                              16
# 4                                   3                              13
#
#    desempenho  satisfacao_com_relacionamento  anos_de_trabalho  \
# 0           3                              2              25.0
# 1           4                              4              21.0
# 2           3                              3               9.0
# 3           3                              2              27.0
# 4           3                              3              24.0
#
#    treinamentos_no_ultimo_ano  equilibrio_vida_trabalho  anos_na_empresa  \
# 0                           2                         3                8
# 1                           2                         3               21
# 2                           3                         4                3
# 3                           2                         3                4
# 4                           1                         4               20
#
#    anos_desde_a_ultima_promocao  anos_com_atual_gestor  target
# 0                             0                      7       0
# 1                             7                      7       0
# 2                             1                      0       0
# 3                             1                      2       0
# 4                            14                     17       0

# %% [markdown]
# # Variaveis categóricas

# %%
cols_cat = df.select_dtypes(include=['object']).columns
df[cols_cat].head(2)
# Out:
#   desligado viagens            departamento campo_da_educacao genero  \
# 0        no  Rarely  Research & Development     Life Sciences   Male
# 1        no  Rarely         Human Resources           Medical   Male
#
#                cargo
# 0  Research Director
# 1            Manager

# %%
le  = LabelEncoder()
hot = OneHotEncoder()

# %%
le.fit_transform(df[cols_cat])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\FELIPE~1\AppData\Local\Temp/ipykernel_9796/4140536858.py in <module>
# ----> 1 le.fit_transform(df[cols_cat])
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     253         y : array-like of shape [n_samples]
#     254         """
# --> 255         y = column_or_1d(y, warn=True)
#     256         self.classes_, y = _encode(y, encode=True)
#     257         return y
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     843         return np.ravel(y)
#     844
# --> 845     raise ValueError(
#     846         "y should be a 1d array, "
#     847         "got an array of shape {} instead.".format(shape))
#
# ValueError: y should be a 1d array, got an array of shape (1352, 6) instead.

# %%
df[cols_cat]
